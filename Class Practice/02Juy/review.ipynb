# %%
review=[
    {"negative":"This is very bad product i ordered one month ago",
     "positive": "This is product is very nice go for it.",
     "bad_products": ["Shoes", "Cricket Bat"],
     "good_products": ["Books","Mobiles phone"]
     },
]
with open ("review.txt","w") as f:
    f.write(review[0]["positive"] + "\n" + ", ".join(review[0]["good_products"])) # .join converts list into string
print("Data inserted successfully")
# Out:
# Data inserted successfully
