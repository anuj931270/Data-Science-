# %%
import json
with open("product.json","r") as file:
    python_data=json.load(file)
    with open("product.txt", "w") as f:
        f.write(str(data))
    print(python_data["id"])
    print(python_data["title"])
    print(python_data["description"])    
    # r=file.read()
    # print(r)
# Out:
# 1
# Essence Mascara Lash Princess
# The Essence Mascara Lash Princess is a popular mascara known for its volumizing and lengthening effects. Achieve dramatic lashes with this long-lasting and cruelty-free formula.

# %%
import mysql.connector

# MySQL database connection
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Root", 
    database="customer"
)

cursor = connection.cursor()
cursor.execute("""
CREATE TABLE products (
    id INT,
    title VARCHAR(100),
    description TEXT,
    category VARCHAR(50),
    price FLOAT,
    discountPercentage FLOAT,
    rating FLOAT,
    stock INT
)
""")

data = {  
    "id": 1,
    "title": "Essence Mascara Lash Princess",
    "description": "The Essence Mascara Lash Princess is a popular mascara known for its volumizing and lengthening effects. Achieve dramatic lashes with this long-lasting and cruelty-free formula.",
    "category": "beauty",
    "price": 9.99,
    "discountPercentage": 7.17,
    "rating": 4.94,
    "stock": 5
}
sql = """
INSERT INTO products 
(id, title, description, category, price, discountPercentage, rating, stock)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
"""
values = (
    data["id"],
    data["title"],
    data["description"],
    data["category"],
    data["price"],
    data["discountPercentage"],
    data["rating"],
    data["stock"]
)

cursor.execute(sql, values)                # Execute insert
connection.commit()                        # Save changes
print("Product inserted successfully!")
cursor.execute("SELECT * FROM products")   # Data display
cursor.execute("SELECT * FROM products")

rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python314\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'products' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[2], line 13
#       9     database="customer"
#      10 )
#      11
#      12 cursor = connection.cursor()
# ---> 13 cursor.execute("""
#      14 CREATE TABLE products (
#      15     id INT,
#      16     title VARCHAR(100),
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python314\Lib\site-packages\mysql\connector\cursor_cext.py:353, in CMySQLCursor.execute(self, operation, params, map_results)
#     345 self._executed = (
#     346     self._stmt_partition["single_stmts"].popleft()
#     347     if map_results
#     348     else self._stmt_partition["mappable_stmt"]
#     349 )
#     351 try:
#     352     self._handle_result(
# --> 353         self._connection.cmd_query(
#     354             self._stmt_partition["mappable_stmt"],
#     355             raw=self._raw,
#     356             buffered=self._buffered,
#     357             raw_as_string=self._raw_as_string,
#     358         )
#     359     )
#     360 except MySQLInterfaceError as err:
#     361     if hasattr(err, "errno"):
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python314\Lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python314\Lib\site-packages\mysql\connector\connection_cext.py:781, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     779 except MySQLInterfaceError as err:
#     780     if hasattr(err, "errno"):
# --> 781         raise get_mysql_exception(
#     782             err.errno, msg=err.msg, sqlstate=err.sqlstate
#     783         ) from err
#     784     raise InterfaceError(str(err)) from err
#     785 except AttributeError as err:
#
# ProgrammingError: 1050 (42S01): Table 'products' already exists
