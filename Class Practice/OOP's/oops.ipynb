# %% [markdown]
# # OOP
# Python is an object-oriented language, allowing you to structure your code using classes and objects for better organization and reusability.
#
# A programming method that oraganizes code around objects "bundles" of data (attributes) and (behaviour/functionality) instead of just function and logics operating on raw data.
# # Advantages of OOP
# Provides a clear structure to programs
#
# Makes code easier to maintain, reuse, and debug
#
# Helps keep your code DRY (Don't Repeat Yourself)
#
# Allows you to build reusable applications with less code
# # Class
# The class keyword is used to create a class.
#
# Instantiation means creating an object from a class.
#
# A class is like an object constructor.
# # Object
# Almost everything in Python is an object, with its properties and methods.
#
# A Class is like an object constructor, or a "blueprint" for creating objects.
# # The __init__() Method
# All classes have a built-in method called __init__(), which is always executed when the class is being initiated.
#
# The __init__() method is used to assign values to object properties, or to perform operations that are necessary when the object is being created.
#
# __init__() is a constructor. It runs automatically when an object is created

# %%
class MyClass: #Each object is independent and has its own copy of the class properties.
  x = 5

p1 = MyClass()
p2 = MyClass()
p3 = MyClass()


print(p1.x)
print(p2.x)
print(p3.x)
# Out:
# 5
# 5
# 5

# %%
# Create a class called Dog
# Add an __init__ method with parameters name and age, and store them as properties using self
# Add a method called bark that prints the dog's name followed by " says Woof!"
# Create an object d1 of the Dog class with name "Buddy" and age 3
# Call the bark method on d1
 
class Dog:                                  #Create a Class and the name is Dog
    def __init__(self,name,age):            #Constructor (__init__)
        self.name=name                      #Store Values in Object Properties
        self.age=age
    def bark(self):
        print(self.name, "says Woof!")
d1=Dog("Buddy", 3)                          #we create an object
d1.bark()
# Out:
# Buddy says Woof!

# %%
# Create a class called Person
# Add an __init__ method that takes name and age as parameters
# Add a method called greet that prints "Hello, my name is " followed by the name
# Create an object p1 of the class with name "John" and age 36
# Call the greet method on p1


class Person:                      #Create a Class
    def __init__(self, name, age): #Constructor (__init__)
        self.name = name           #self.name stores the name.
        self.age = age             #self.age stores the age.

    def greet(self):               #This method prints the person's name.
        print("Hello, my name is", self.name) 


p1 = Person("John", 36) #Create an Object

p1.greet() #Call the Method
# Out:
# Hello, my name is John

# %%
class Whatsapp_v1:
    chat_features="Available"
    vc_feature="Not Available"

    def sticker(self):
        return "Sending Sticker...❤️"

class Whatsapp_v2(Whatsapp_v1):
    vc_feature="Available"

class Facebook_v1:
    sharing_facebook="Available"

class Whatsapp_v3(Whatsapp_v2,Facebook_v1):
    status_feature="Available"

user=Whatsapp_v3()
user.sticker()
# Out:
# 'Sending Sticker...❤️'

# %%
class Bank_v1:
    bank_name = "ABC Bank"

    def __init__(self, name, balance, cibil_score):
        self.name = name
        self.balance = balance
        self.cibil_score = cibil_score

    def account_details(self):
        return f"Customer Name : {self.name}\nBalance : ₹{self.balance}"


class Bank_v2(Bank_v1):

    def withdraw(self, amount):
        if self.balance >= 5000:
            return "Minimum Balance Maintained. No Extra Charges."
        elif self.balance >= amount:
            self.balance -= amount
            return f"₹{amount} Withdrawn Successfully.\nRemaining Balance : ₹{self.balance}"
        else:
            return "Insufficient Balance."

    def rupay_card(self):
        return "RuPay Debit Card Activated Successfully."

    def debit_card(self):
        return "Debit Card Available."

    def upi(self):
        return "UPI Service Activated."

    def net_banking(self):
        return "Net Banking Activated Successfully."


class Loan_v1(Bank_v2):

    def loan_eligibility(self):
        if self.cibil_score >= 750:
            return "Eligible for Home Loan, Car Loan and Personal Loan."
        else:
            return "Not Eligible for Loan."

    def apply_loan(self, amount):
        if self.cibil_score >= 750:
            return f"Loan of ₹{amount} Approved."
        else:
            return "Loan Application Rejected."


class Card_v1(Loan_v1):

    def credit_card(self):
        if self.cibil_score >= 700:
            return "Credit Card Approved."
        else:
            return "Credit Card Rejected."

    def premium_card(self):
        if self.balance >= 100000:
            return "Eligible for Premium RuPay Credit Card."
        else:
            return "Not Eligible for Premium Card."


class Bank_System(Card_v1):
    pass


# Object Creation
customer = Bank_System("Anuj", 120000, 780)

print(customer.account_details())
print(customer.withdraw(2000))
print(customer.loan_eligibility())
print(customer.apply_loan(500000))

print(customer.rupay_card())
print(customer.debit_card())
print(customer.credit_card())
print(customer.premium_card())

print(customer.upi())
print(customer.net_banking())
# Out:
# Customer Name : Anuj
# Balance : ₹120000
# Minimum Balance Maintained. No Extra Charges.
# Eligible for Home Loan, Car Loan and Personal Loan.
# Loan of ₹500000 Approved.
# RuPay Debit Card Activated Successfully.
# Debit Card Available.
# Credit Card Approved.
# Eligible for Premium RuPay Credit Card.
# UPI Service Activated.
# Net Banking Activated Successfully.

# %%
# What is constructor?
# A Constructor is a special method that runs automatically the movement an object created.
#__init__(): Constructor Method

# %%
class stu:
    def __init__(self,name,age,city,roll_no):
        self.name=name
        self.age=age
        self.city=city
        self.roll_no=roll_no
    def show_details(self):
        print(f"Student Name : {self.name}")
        print(f"Student Age : {self.age}")
        print(f"Student City : {self.city}")



        
st1=stu("Anuj",22,"Delhi",847223)
st1.show_details()
# Out:
# Student Name : Anuj
# Student Age : 22
# Student City : Delhi

# %%
# Student Manage Sysytem
# main class student
# add stu features
# get all stu features
# get stu by roll no features
# update stu features
# delete student features


class Student:
    def __init__(self):
        self.students = {}

    def add_student(self, roll_no, name, age, city):
        if roll_no in self.students:
            print(f"Student with Roll No {roll_no} already exists.")
            return

        self.students[roll_no] = {
            "name": name,
            "age": age,
            "city": city
        }
        print(f"Student {name} added successfully.")

    def get_all_students(self):
        if not self.students:
            print("No Students Found.")
            return

        for roll_no, details in self.students.items():
            print(f"Roll No : {roll_no} | Name : {details['name']} | Age : {details['age']} | City : {details['city']}")

    def get_student_by_roll(self, roll_no):
        if roll_no not in self.students:
            print("Student Not Found.")
            return

        details = self.students[roll_no]
        print(f"Roll No : {roll_no}")
        print(f"Name    : {details['name']}")
        print(f"Age     : {details['age']}")
        print(f"City    : {details['city']}")

    def update_student(self, roll_no, name, age, city):
        if roll_no not in self.students:
            print("Student Not Found.")
            return

        self.students[roll_no] = {
            "name": name,
            "age": age,
            "city": city
        }

        print("Student Updated Successfully.")

    def delete_student(self, roll_no):
        if roll_no not in self.students:
            print("Student Not Found.")
            return

        del self.students[roll_no]
        print("Student Deleted Successfully.")

# %%
# Object Creation
s = Student()

# %%
# Add Students
s.add_student(100, "Aman", 33, "Noida")
s.add_student(101, "Rahul", 22, "Delhi")
s.add_student(102, "Priya", 21, "Lucknow")
# Out:
# Student Aman added successfully.
# Student Rahul added successfully.
# Student Priya added successfully.

# %%
print("\nAll Students") #new line
s.get_all_students()
# Out:
# All Students
# Roll No : 100 | Name : Aman | Age : 33 | City : Noida
# Roll No : 101 | Name : Rahul | Age : 22 | City : Delhi
# Roll No : 102 | Name : Priya | Age : 21 | City : Lucknow

# %%
print("\nStudnet By Roll No")
s.get_student_by_roll(102)
# Out:
# Studnet By Roll No
# Roll No : 102
# Name    : Priya
# Age     : 21
# City    : Lucknow

# %%
print("\nUpdate Student")
s.update_student(102,"Priya Pathak",22,"Gurgaon")
s.get_student_by_roll(102)
# Out:
# Update Student
# Student Updated Successfully.
# Roll No : 102
# Name    : Priya Pathak
# Age     : 22
# City    : Gurgaon

# %%
print("\nDelete Student")
s.delete_student(102)
# Out:
# Delete Student
# Student Deleted Successfully.

# %%
print("\nAll students")

s.get_all_students()
# Out:
# All students
# Roll No : 100 | Name : Aman | Age : 33 | City : Noida
# Roll No : 101 | Name : Rahul | Age : 22 | City : Delhi

# %% [markdown]
# # Inheritance
# When one class (child/derived) reuses and functionality from another class(parent/base) known as inheritance.
#
# Inheritance is a feature where one class acquires the properties (variables) and methods (functions) of another class.
#
# # Types of Inheritance in Python
# 1. Single Inheritance
#
# 2. Multiple Inheritance
#
# 3. Multilevel Inheritance
#
# 4. Hierarchical Inheritance
#
# 5. Hybrid Inheritance

# %%
# Single Inheritance :- One parent → One child.
class Parent:
    def show(self):
        print("Parent Method")

class Child(Parent):
    pass

obj = Child()
obj.show()
# Out:
# Parent Method

# %%
#Multiple Inheritance :- One child inherits from multiple parents.

class Father:
    def money(self):
        print("Father gives money")

class Mother:
    def care(self):
        print("Mother gives care")

class Child(Father, Mother):
    pass

obj = Child()

obj.money()
obj.care()
# Out:
# Father gives money
# Mother gives care

# %%
#3. Multilevel Inheritance :- A child becomes the parent of another class.  

class GrandParent:
    def home(self):
        print("Grandparent's Home")

class Parent(GrandParent):
    pass

class Child(Parent):
    pass

obj = Child()
obj.home()
# Out:
# Grandparent's Home

# %%
#4. Hierarchical Inheritance :- One parent has multiple children.
class Animal:
    def eat(self):
        print("Eating")

class Dog(Animal):
    pass

class Cat(Animal):
    pass

dog = Dog()
cat = Cat()

dog.eat()
cat.eat()
# Out:
# Eating
# Eating

# %% [markdown]
# # Encapsulation
# Encapsulation is an Object-Oriented Programming (OOP) concept that wraps data (variables) and methods (functions) into a single unit called a class. It also restricts direct access to some data to protect it from accidental changes.
#
# # Why do we use Encapsulation?
# Protect data from unauthorized access.
#
# Hide internal implementation.
#
# Improve security.
#
# Reduce bugs.
#
# Make code easier to maintain.
# # What are the access modifiers in Python?
# Public,
# Protected,
# Private.

# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def student_result(self):
        print(self.__name)
        print(self.__marks)

    def set_marks(self,marks):
        if 0<= marks <=100:
            self.__marks=marks
        else:
            print("Invalid Marks...")
    def get_marks(self):
        return self.__marks

# %%
s=Student("Anuj",88)
s.student_result()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 s=Student("Anuj",88)
# ----> 2 s.student_result()
#
# Cell In[16], line 6, in Student.student_result(self)
#       5     def student_result(self):
# ----> 6         print(self.__name)
#       7         print(self.__marks)
#
# AttributeError: 'Student' object has no attribute '_Student__name'

# %%
s.set_marks(55)

# %%
s.student_result()
# Out:
# Anuj
# 88
