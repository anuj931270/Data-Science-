# %% [markdown]
# # Dictionary
#
# Dictionaries are used to store data values in key:value pairs.
#
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
#
# dictionaries are unordered.
#
# Dictionaries are written with curly brackets, and have keys and values:
#
# Dictionary items are ordered, changeable, and do not allow duplicates.
#
# Dictionary items are presented in key:value pairs, and can be referred to by using the key name.
#
# # Update Dictionary
# The update() method will update the dictionary with the items from the given argument.

# %%
# Create and print a dictionary:
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
stu_marks=dict([('anuj',300) ,("anup",80)])
print(stu_marks)
# Out:
# {'anuj': 300, 'anup': 80}

# %%
# change the add
stu_profile={"aman":"noida","anuj":"delhi"}
stu_profile["aman"]="gurgaon"
print(stu_profile)
# Out:
# {'aman': 'gurgaon', 'anuj': 'delhi'}

# %%
stu_marks={'aman': 300, 'alok':80, 'rohan':40,'abhi':44}
for i in stu_marks:
    stu_marks[i]=stu_marks[i]*2
print(stu_marks)
# Out:
# {'aman': 600, 'alok': 160, 'rohan': 80, 'abhi': 88}

# %%
stu_marks={'aman': 300, 'alok':80, 'rohan':40,'abhi':44}
v=stu_marks.values()
k=stu_marks.keys()
i=stu_marks.items()
res=stu_marks.get("anuj","N/A")
print(v)
print(k)
print(i)
print(res)
# Out:
# dict_values([300, 80, 40, 44])
# dict_keys(['aman', 'alok', 'rohan', 'abhi'])
# dict_items([('aman', 300), ('alok', 80), ('rohan', 40), ('abhi', 44)])
# N/A

# %%
stu_marks={'aman': 300, 'alok':80, 'rohan':40,'abhi':44}
new_marks={'kanu': 400, 'bhanu':180}
stu_marks.update(new_marks)
print(stu_marks)
# Out:
# {'aman': 300, 'alok': 80, 'rohan': 40, 'abhi': 44, 'kanu': 400, 'bhanu': 180}

# %%
profile={
    'aman':{
        'address':["Noida","Delhi","Mumbai"],
        'hobbies':["reading","cooking","playing"],
        'password':{"insta":"8795112","fb":"4785594"},
        },
    'anuj':{
        'address':["Noida","Delhi","Mumbai","gurgaon"],
        'hobbies':["reading","cooking","playing"],
        'password':{"insta":"000000","fb":"4785594"},
    },
}
res=profile["aman"]["password"]["insta"]
res1=profile["anuj"]["password"]["insta"]
print(res)
print(res1)
# Out:
# 8795112
# 000000
