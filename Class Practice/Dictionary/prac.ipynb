# %%
student = {
    "name": "Anuj",
    "age": 22,
    "city": "Ghaziabad"
}

print(student)
# Out:
# {'name': 'Anuj', 'age': 22, 'city': 'Ghaziabad'}

# %%
# dict_name = {
#     key1: value1,
#     key2: value2
# }
person = {
    "name": "Aman",
    "age": 25
}
student = {"name": "Anuj", "age": 22}

print(student["name"])
# Out:
# Anuj

# %%
student = {"name": "Anuj", "age": 22}

print(student.get("age"))
# Out:
# 22

# %%
# Count Frequency
nums = [1, 2, 2, 3, 1, 2]
freq = {}

for i in nums:
    freq[i] = freq.get(i, 0) + 1
print(freq)
# Out:
# {1: 2, 2: 3, 3: 1}
