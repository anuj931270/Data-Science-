# %%
student = {
    "name": "Anuj",
    "age": 22,
    "city": "Ghaziabad"
}

print(student)
# Out:
# {'name': 'Anuj', 'age': 22, 'city': 'Ghaziabad'}

# %%
# dict_name = {
#     key1: value1,
#     key2: value2
# }
person = {
    "name": "Aman",
    "age": 25
}
student = {"name": "Anuj", "age": 22}

print(student["name"])
# Out:
# Anuj

# %%
student = {"name": "Anuj", "age": 22}

print(student.get("age"))
# Out:
# 22

# %%
# Count Frequency
nums = [1, 2, 2, 3, 1, 2]
freq = {}

for i in nums:
    freq[i] = freq.get(i, 0) + 1
print(freq)
# Out:
# {1: 2, 2: 3, 3: 1}

# %%
student = {
    "name":"anuj",
    "subjects":("math","science"),
    "skills":"python",
    "subject":["java","c++"],
    "is_adult":True,
    "scores":{              #nested dictionary  
        "aman":85,
        "annu":90,
        "alok":95
    }
}
null_dict={}
print(null_dict)
print(student)
print(len(student))
print(student["scores"])
print(type(student))
print(student.keys())
print(list(student.keys()))
print(student.values())
pairs=list(student.items())
# print=(pairs[0])
# # print(student["name"])
# print(student.get("name"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 14
#      10         "alok":95
#      11     }
#      12 }
#      13 null_dict={}
# ---> 14 print(null_dict)
#      15 print(student)
#      16 print(len(student))
#      17 print(student["scores"])
#
# TypeError: 'tuple' object is not callable

# %%
student = {
    "name":"anuj",
    "subjects":("math","science"),
    "skills":"python",
    "subject":["java","c++"]
}
print(student["name"])
# Out:
# anuj
