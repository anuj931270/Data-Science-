# %% [markdown]
# # Defination and property of string.
# String is a data structure used to store sequence of char,num,symbols.
# String are immutable
# String support indexing,slicing,and ordered.

# %%
# creation of string
user_name="aman"
print(user_name.isupper())
print(user_name.islower())
# Out:
# False
# True

# %%
# creation of string
user_name="aman"
print(user_name.upper())
print(user_name.lower())
print(user_name.capitalize())
# Out:
# AMAN
# aman
# Aman

# %%
user="Aman"
new_string=user.replace("a","y")
print(new_string)
# Out:
# Amyn

# %%
user="Aman"
new_string="".join(user)
print(new_string)
# Out:
#     Aman

# %%
user="     Aman         "
print(user.strip())
# Out:
# Aman

# %%
user="Aman"
print(user.endswith('3'))
print(user.startswith('1'))
# Out:
# False
# False

# %%
user="Aman"
i=user.find ('n')
print(i)
# Out:
# 3

# %%
user="Aman"
i=user.index ('n', 1)
print(i)
# Out:
# 3

# %%
string="This is python for data-science"
lis=string.split()
print(lis)
# Out:
# ['This', 'is', 'python', 'for', 'data-science']

# %%
string="anuj785"
lis=string.isalnum()
print(lis)
# Out:
# True

# %%
string="anuj"
lis=string.isalpha()
print(lis)
# Out:
# True

# %%
# regex operation()
# remove duplicate char
# string alternatively upper.

# %%
# string="This is python for data-science"

# %%
# waf to remove last word from string
# waf to remove words if vowel present from string
# waf to count total whitespace in string
# waf to extract only numbers for string
# waf to remove print all special symbols
# waf ro reverse all words of string
# waf to remove all whitespace for string

# %%
# waf to remove last word from string
str1 = "This is python code"
str1 = str1.rsplit(" ",1)[0]
print(str1)
# Out:
# This is python

# %%
# waf to remove words if vowel present from string
str1 = "This is python code"
vowel="aeiouAEIOU"
for i in str1:
    if i in vowel:
        print(i)
# Out:
# i
# i
# o
# o
# e

# %%
# waf to count total whitespace in string
str1 = "This is python code"
count=0
for i in str1:
    if i.isspace():
        count+=1
print("total whitespace",count)
# Out:
# total whitespace 3

# %%
# waf to remove all whitespace for string
str1 = "This is python code"
result = str1.replace(" ", "")
print(result)
# Out:
# Thisispythoncode

# %%
# waf ro reverse all words of string
str1 = "This is python code"
reverse=str1[::-1]
print(reverse)
# Out:
# edoc nohtyp si sihT

# %%
# waf to remove print all special symbols
str1 = "This is python code anuj@ aman$ anup#"

# %%
# waf convert list into uppercase
words = ["apple", "banana", "cherry"]
uppercase_words = []

for word in words:
    uppercase_words.append(word.upper())

print(uppercase_words)
# Out:
# ['APPLE', 'BANANA', 'CHERRY']

# %%
char=["Ram","rohit","rohan"]
vwls="aeiouAEIOU"
for i in char:
    for j in i:
        if j in vwls:
            print(j)
# Out:
# a
# o
# i
# o
# a

# %%
str1="this  is a cat"
str2=""
for i in str1:
    if i not in "aeiou":
        str2+=i
print(str2)
# Out:
# ths  s  ct

# %%
str1="this  is a cat"
v="aeiou"
for i in range(len(str1)):
    if str1[i] in v:
        print(str1[i],i)
# Out:
# i 2
# i 6
# a 9
# a 12

# %%
num=["Even" if i %2 ==0 else "odd" for i in range(6)]
print(num)
# Out:
# ['Even', 'odd', 'Even', 'odd', 'Even', 'odd']

# %%
def sum(a,b):
    return a+b
num= sum(5,3)
print(num)
# Out:
# 8

# %%
str1="this is python 7844"
ele="".join([i for i in str1 if i.isdigit()])
print(ele)
# Out:
# 7844

# %%
mylist=[20,10,22,24,9]
nl=[]
for i in mylist:
        if i%2==0:
             nl.append(f"{i} even")
        else:
           nl.append(f"{i} odd")
print(nl)
# Out:
# ['20 even', '10 even', '22 even', '24 even', '9 odd']

# %%
mylist=["python programming"]
reverse_str1=mylist[0][::-1]
reverse=[reverse_str1]
print(reverse)
# Out:
# ['gnimmargorp nohtyp']

# %%
mylist=["python programming"]
# for i in mylist:
#     rev=i[::-1]
#     print(rev.replace('g', '_').replace('n', 'g').replace('_', 'n'))
print(mylist[0][::-1].replace('g', '_').replace('n', 'g').replace('_', 'n'))
# Out:
# ngimmarnorp gohtyp

# %%
n1 = 20
n2 = 2
n3 = 10
if n1>n2 and n1>3:
    print("n1 is largest")
elif n2>n3 and n2>n1:
    print("n2 is largest")
else:
    n3>n1
    print("n3 is largest")
# Out:
# n1 is largest
