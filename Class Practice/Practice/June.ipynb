# %%
str1="anuj pathak"
a=0
for i in str1:
    a= a+1
print(a)
# Out:
# 11

# %%
str1 = "anuj pathak"
index = 0

for i in str1:
    print(f"Character '{i}' is at index {index}")
    index = index + 1
# Out:
# Character 'a' is at index 0
# Character 'n' is at index 1
# Character 'u' is at index 2
# Character 'j' is at index 3
# Character ' ' is at index 4
# Character 'p' is at index 5
# Character 'a' is at index 6
# Character 't' is at index 7
# Character 'h' is at index 8
# Character 'a' is at index 9
# Character 'k' is at index 10

# %%
str1 = "anuj pathak"

for i in range(len(str1)):
    print(str1[i], i)
# Out:
# a 0
# n 1
# u 2
# j 3
#   4
# p 5
# a 6
# t 7
# h 8
# a 9
# k 10

# %%
def check_odd_even(n):
    if n%2 == 0:
        return "Even"
    else:
        return "Odd"
res=check_odd_even(14)
print(res)
# Out:
# Even

# %%
def add(a, b):
    print(a+b)
add(40,6)
# Out:
# 46

# %%
def nameAge(name, age):
    print("Hy, I am ",name)
    print("My age is",age)
print("case-1:")
nameAge("Alok", 25)
print("case-2:")
nameAge("Anup", 24)
# Out:
# case-1:
# Hy, I am  Alok
# My age is 25
# case-2:
# Hy, I am  Anup
# My age is 24

# %%
def fun(*args):
    return sum(args)
print(fun(5,10,15))
# Out:
# 30

# %%
def fun(**kwargs):
    for k, val in kwargs.items():
        print(k,val)
fun(a=1,b=2,c=3)
# Out:
# a 1
# b 2
# c 3
