# %%
string="this is python class"
user=input("Enter Your vowel (a,e,i,o,u):")
if user =="a" or user =="e" or user =="i" or user =="o" or user =="u"  in string:
    print(f"Yes {user} is vowel")
else:
    print(f"'{string}' in this string {user} is not present")
# Out:
# Enter Your vowel (a,e,i,o,u): a
# Yes a is vowel

# %%
Gmail= input("Enter your mail")
find = "gmail.com"
if find in Gmail:
    print("Valid Mail")
else:
    print("Invalid Mail")
# Out:
# Enter your mail fdshfoihsfhhs@hotmail.com
# Invalid Mail

# %%
user_url= input("Enter Your Website")
valid= "https://"
if valid in user_url:
    print("this website in not safe")
else:
    print(user_url)
# Out:
# Enter Your Website https://gfuigdsifgiu
# this website in not safe

# %%
marks = 100
if marks >= 80:
    print("PASS-1")
if marks >= 90:
    print("PASS-2")
if marks >= 75:
    print("PASS-3")
else:
    peint("Nothing")
# Out:
# PASS-1
# PASS-2
# PASS-3

# %%
num1 =4
num2 =9
num3 =3
if (num2 > num1 > num3) or (num3 > num1 > num2):
    print(num1)
elif (num1 > num2 > num3) or (num3 > num2 > num1):
    print(num2)
else:
    print(num3)
# Out:
# 4
