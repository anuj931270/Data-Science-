# %%
marks=[85,55,33,85,25,14,66,23,145,22,99]
odd_count=0
for i in marks:
    if i%2!=0:
        odd_count+=1
        print("odd count: ",odd_count)
# Out:
# odd count:  1
# odd count:  2
# odd count:  3
# odd count:  4
# odd count:  5
# odd count:  6
# odd count:  7
# odd count:  8

# %% [markdown]
# # 18 June

# %%
marks=[85,55,33,85,25,14,66,23,145,22,99]
m=marks[0]
for i in (range(marks)):
    if marks[i]<m:
        m=marks[i]
print(m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 marks=[85,55,33,85,25,14,66,23,145,22,99]
#       2 m=marks[0]
# ----> 3 for i in (range(marks)):
#       4     if marks[i]<m:
#       5         m=marks[i]
#       6 print(m)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
#append
marks=[88,55,48,22,49,86]
marks.append(888)
print(marks)
# Out:
# [88, 55, 48, 22, 49, 86, 888]

# %%
# extend
marks=[88,55,48,22,49,86]
line=("bus", False, 748, "apple")
marks.extend(line)
print(marks)
# Out:
# [88, 55, 48, 22, 49, 86, 'bus', False, 748, 'apple']

# %%
#insert
marks=[88,55,48,22,49,86]
marks.insert(2,"anuj")
print(marks)
# Out:
# [88, 55, 'anuj', 48, 22, 49, 86]

# %%
# pop
marks=[88,55,48,22,49,86,77,89]
n1=marks.pop()
n2=marks.pop()
print(marks)
print(n1,n2)
# Out:
# [88, 55, 48, 22, 49, 86]
# 89 77

# %%
# clear
marks=[88,55,48,22,49,86]
marks.clear()
print(marks)
# Out:
# []

# %%
# reverse
marks=[88,55,48,22,49,86]
marks.reverse()
print(marks)
# Out:
# [86, 49, 22, 48, 55, 88]

# %%
# count
marks=[88,55,48,22,49,86]
dup=marks.copy()
print(dup)
dup[0]=8858
print(dup)
print(marks)
# Out:
# [88, 55, 48, 22, 49, 86]
# [8858, 55, 48, 22, 49, 86]
# [88, 55, 48, 22, 49, 86]

# %%
marks=[88,55,48,22,49,86]
for i in range (len(marks)):
    marks[i]=0
print(marks)
# Out:
# [0, 0, 0, 0, 0, 0]

# %%
thislist = ["apple", "banana", "cherry"]
vowels = "aeiouAEIOU"

for i in thislist:
    for ch in i:
        if ch in vowels:
            print(ch)
# Out:
# a
# e
# a
# a
# a
# e

# %%
thislist = ["apple", "banana", "cherry"]
vowels="aeiou"
store=""
for i in thislist:
    store+=i
for j in store:
    if j in "aeiou":
        vowels+=j
print(vowels)
# Out:
# aeiouaeaaae

# %%
marks=int(input[88,55,48,22,49,86])
marks_tag=['55:pass', '22:fail']
for i in
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 marks=int(input[88,55,48,22,49,86])
#       2 marks_tag=['55:pass', '22:fail']
#       3 for i in marks>=55:
#       4     print("pass")
#
# TypeError: 'method' object is not subscriptable

# %%
marks = [88, 55, 48, 22, 49, 86]
marks_tag = []
for m in marks:
    if m >= 55:
        marks_tag.append(f"{m}:pass")
    elif m <= 22:
        marks_tag.append(f"{m}:fail")
print(marks_tag)
# Out:
# ['88:pass', '55:pass', '22:fail', '86:pass']

# %%
data_list=["alok", 78, True,False,[5,10],68,10.5]
data_list_type[]
# Out:
#   Cell In[52], line 2
#     data_list_type[]
#                    ^
# SyntaxError: invalid syntax

# %%
mylist = ['apple', 'banana', 'cherry']
i = 0
while i <len(mylist):
    print(mylist[i])
    i = i + 1
# Out:
# apple
# banana
# cherry

# %%
def odd(a,b):
    odd_num=[]
    for i in range (a,b+1):
        if i%2!=0:
            odd_num.append(i)
    return(odd_num)
print(odd(10,19))
# Out:
# [11, 13, 15, 17, 19]

# %%
def odd(a,b):
    odd_num=[i for i in range(a,b) if i%2!=0]
    return odd_num
print(odd(10,21))
# Out:
# [11, 13, 15, 17, 19]

# %%
# search name char wise use list compr.
emp_name = ["anuj", "aman", "shivam", "rohan"]
search_char = "j"
matching_names = [name for name in emp_name if search_char in name]
print(matching_names)
# Out:
# ['anuj']

# %%
def find(emp_name,search):
    return[name for name in emp_name if search in name]
emp_name = ["anuj", "aman", "shivam", "rohan"]
res=search_char(emp_name,"x")
if res==[]:
    print("Result not found")
else:
    print(res)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 4
#       1 def find(emp_name,search):
#       2     return[name for name in emp_name if search in name]
#       3 emp_name = ["anuj", "aman", "shivam", "rohan"]
# ----> 4 res=search_char(emp_name,"x")
#       5 if res==[]:
#       6     print("Result not found")
#       7 else:
#
# TypeError: 'str' object is not callable

# %%
import pymysql
def my_db(data_list):
    db=pymysql.connect(host="localhost",user="root",password="Root")
    cur=db.cursor()
    [cur.execute(f"CREATE DATABASE {i}") for i in data_list]
    cur.execute(f"Show databases")
    print(cur.fetchall())
    print("Database Created")
target_db_name=['staff','students','employees']
my_db(target_db_name)
# Out:
# (('4june',), ('anuj',), ('anuj_db',), ('batch_118',), ('customer',), ('db1',), ('ecom',), ('employees',), ('information_schema',), ('june',), ('mysql',), ('performance_schema',), ('sakila',), ('staff',), ('student_management',), ('students',), ('sys',), ('world',))
# Database Created

# %% [markdown]
# # 19June

# %%
# Creating lists
fruits = ["apple", "banana", "cherry"]
numbers = [1, 2, 3, 4, 5]
mixed = [42, "hello", True, 3.14]  # Lists can hold different data types

# Accessing items (Indexing starts at 0)
print(fruits[0])   # Output: apple
print(fruits[-1])  # Output: cherry (Negative indexing starts from the end)

# Modifying items
fruits[1] = "blueberry"
print(fruits)      # Output: ['apple', 'blueberry', 'cherry']
# Out:
# apple
# cherry
# ['apple', 'blueberry', 'cherry']

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# Accessing the number 6 (Row 1, Column 2)
print(matrix[2][1])  # Output: 6
# Out:
# 8

# %% [markdown]
# # Question:
# Loop through the list ["Python", "Java", "C++"] and print each item with its index position (e.g., "0: Python").

# %%
list= ["Python", "Java", "C++"]
for index, lis in enumerate(list):
    print(f"{index}:{list}")
# Out:
# 0:['Python', 'Java', 'C++']
# 1:['Python', 'Java', 'C++']
# 2:['Python', 'Java', 'C++']

# %% [markdown]
# # Question:
# Given a list of numbers, calculate their total sum without using the built-in sum() function.

# %%
num=[45,55,72,22,15]
total_sum=0
for n in num:
    total_sum += n
print("Total: ",total_sum)
# Out:
# Total:  209

# %% [markdown]
# # 20June
