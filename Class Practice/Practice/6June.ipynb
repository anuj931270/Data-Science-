# %%
for i in range(3):
    for j in range(2):
        print(i,"=",j)
# Out:
# 0 = 0
# 0 = 1
# 1 = 0
# 1 = 1
# 2 = 0
# 2 = 1

# %%
#nested for loop
for i in range(3):
    print("10")
    for j in range(2):
        print("15")
# Out:
# 10
# 15
# 15
# 10
# 15
# 15
# 10
# 15
# 15

# %%
ap="python"
for i in range(len(ap)):
    print(ap[i],"python",i)
# Out:
# p python 0
# y python 1
# t python 2
# h python 3
# o python 4
# n python 5
