# %%
nitin_age= 23
anuj_age=22
if nitin_age>=anuj_age:
    print("YES")
else:
    print("NO")
# Out:
# YES

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
        print("Even number")
else:
        print("Odd number")
# Out:
# Enter a number:  13
# Odd number

# %%
age = int(input("Enter your age:"))
if age<=18:
    print("Not Eligible for vote")
else:
    print("Eligible for vote")
# Out:
# Enter your age: 15
# Not Eligible for vote

# %%
age = int(input("Enter your age:"))
if age<=45:
    print("Not Eligible for PM")
else:
    print("Eligible for PM")
# Out:
# Enter your age: 48
# Eligible for PM

# %%
student_score = int(input("Enter the student's score"))
if student_score >= 90:
    print("grade A")
elif student_score >= 85:
    print("grade B")
elif student_score >= 60:
    print("grade C")
else:
    print("fail")
# Out:
# Enter the student's score 45
# fail

# %%
age1 = 25
age2 = 30
if age1>20 and age2>40:
    print("True")
else:
    print("False")
# Out:
# False

# %%
age1 = 25
age2 = 30
if age1>20 or age2>40:
    print("True")
else:
    print("False")
# Out:
# True

# %%
age1 = 25
age2 = 30
if not(age1>20 or age2>40):
    print("True")
else:
    print("False")
# Out:
# False

# %%
number = int(input("Enter a number: "))
if number % 2 == 0 and number % 3 == 0:
    print("Number is completely divide")
else:
    print("Number is not divide")
# Out:
# Enter a number:  12
# Number is completely divide

# %%
user_mob_no = int(input("Enter the mobile number"))
if len(user_mob_no)==10:
    print("Valid")
else:
    print("Invalid")
# Out:
# Enter the mobile number 7777777777
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 user_mob_no = int(input("Enter the mobile number"))
# ----> 2 if len(user_mob_no)==10:
#       3     print("Valid")
#       4 else:
#       5     print("Invalid")
#
# TypeError: object of type 'int' has no len()
