# %%
# Write a program to calculate the sum of all keys in the dictionary
# d = {1: 1, 2: 2, 3: 3, 4: 4}

d = {1: 1, 2: 2, 3: 3, 4: 4}
total_sum=0

for i in d:
    total_sum+=i
print("The sum of all keys is :",total_sum)
# Out:
# The sum of all keys is : 10

# %%
# Write a program to calculate the sum of both keys and values in the dictionary
# d = {1: 1, 2: 2, 3: 3, 4: 4}

# Define the dictionary
d = {1: 1, 2: 2, 3: 3, 4: 4}

# Calculate the sum of keys and the sum of values, then add them together
total_sum = sum(d.keys()) + sum(d.values())

# Print the result
print(f"The sum of both keys and values is: {total_sum}")
# Out:
# The sum of both keys and values is: 20

# %%
# Create an empty dictionary called user_data.
# Allow the user to enter key-value pairs until they choose to stop.
# Print the final dictionary.

# Create an empty dictionary
user_data = {}

while True:
    # Take key and value from the user
    key = input("Enter key: ")
    value = input("Enter value: ")

    # Store in dictionary
    user_data[key] = value

    # Ask if the user wants to continue
    choice = input("Do you want to add another key-value pair? (yes/no): ").lower()

    if choice == "no":
        break

# Print the final dictionary
print("\nFinal Dictionary:")
print(user_data)
# Out:
# Final Dictionary:
# {'12': '25'}

# %%
# Write a program to calculate the total score of all students
# student_score = {1: 44, 2: 45, 3: 55}

student_score = {1: 44, 2: 45, 3: 55}

total_sum = 0

for score in student_score.values():
    total_sum += score

print("The total score of all students is:", total_sum)
# Out:
# The total score of all students is: 144

# %%
# Write a program to separate odd and even keys from a dictionary.
# Also count the total number of odd keys and even keys.

student_score = {
    1: 44,
    2: 45,
    3: 55,
    4: 67,
    5: 89,
    6: 90
}

odd_keys=[]
even_keys=[]

odd_count=0
even_count=0

for key in student_score:
    if key % 2==0:
        even_keys.append(key)
        event_count+=1
    else:
        odd_keys.append(key)
        odd_count +=1

print(f"odd_keys {odd_keys} and even_keys {even_keys}")
print(f"odd_count {odd_count} and even_count {even_count}")
# Out:
# odd_keys [1, 3, 5] and even_keys [2, 4, 6]
# odd_count 3 and even_count 0

# %%
# Write a program to find the greatest key in the dictionary
# player = {7: "Dhoni", 12: "Kohli", 9: "Rohit", 89: "Bumrah"}

player = {
    7: "Dhoni",
    12: "Kohli",
    9: "Rohit",
    89: "Bumrah"
    }
greatest=0

for key in player:
    if key>greatest:
        greatest=key
print("greatest key is: ",greatest)
# Out:
# greatest key is:  89

# %%
# Write a program to extract alternate key-value pairs from the dictionary
# player = {7: "Dhoni", 12: "Kohli", 9: "Rohit", 89: "Bumrah"}

player = {
    7: "Dhoni",
    12: "Kohli",
    9: "Rohit",
    89: "Bumrah"
    }

alternate={}

for i, (key, value) in enumerate(player.items()):
     if i % 2 == 0:      # Take alternate items (0, 2, ...)
        alternate[key] = value

print(alternate)
# Out:
# {7: 'Dhoni', 9: 'Rohit'}

# %%
# Write a program to find all values that start with the letter ‘K’
# player = {7: "Dhoni", 12: "Kohli", 9: "Rohit", 89: "Bumrah"}

player = {
    7: "Dhoni",
    12: "Kohli",
    9: "Rohit",
    89: "Bumrah"
    }

for i in player.values():
    if i.startswith("K"):
        print(i)
# Out:
# Kohli

# %%
# Write a program to merge two dictionaries
# d1 = {1: "a", 2: "b"}
# d2 = {3: "c", 4: "d"}

d1 = {1: "a", 2: "b"}
d2 = {3: "c", 4: "d"}

merged={**d1,**d2}
print(merged)
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# %%
# Write a program to check whether a given key exists in the dictionary
# d = {1: 100, 2: 200, 3: 300}

d = {1: 100, 2: 200, 3: 300}
value=d.get(2)
if value is not None:
    print("Key Exist")
else:
    print("Key does not exist")
# Out:
# Key Exist

# %%
# Write a program to find the minimum value in the dictionary
# marks = {"A": 85, "B": 90, "C": 75, "D": 95}

marks = {"A": 85, "B": 90, "C": 75, "D": 95}
min_val = min(marks.values())
print("Minimum value:", min_val)
# Out:
# Minimum value: 75

# %%
# Write a program to find the maximum value in the dictionary
# marks = {"A": 85, "B": 90, "C": 75, "D": 95}

marks = {"A": 85, "B": 90, "C": 75, "D": 95}
max_value=max(marks.values())
print("Maximum value:",max_value)
# Out:
# Maximum value: 95

# %%
# Write a program to swap keys and values in the dictionary
# d = {1: "one", 2: "two", 3: "three"}

d = {1: "one", 2: "two", 3: "three"}
swapped={}
for key,value in d.items():
    swapped[value]=key
print("Swapped dictionary",swapped)
# Out:
# Swapped dictionary {'one': 1, 'two': 2, 'three': 3}

# %%
# Write a program to remove a specific key (for example, key = 2) from the
# dictionary
# d = {1: 10, 2: 20, 3: 30}

d = {1: 10, 2: 20, 3: 30}
key=2
d.pop(key,None)
print("Remove Key",d)
# Out:
# Remove Key {1: 10, 3: 30}

# %%
# Write a program to count the frequency of each character in a string using a
# dictionary.
# Example: "banana"

string = "banana"
freq = {}

for char in string:
    freq[char] = freq.get(char, 0) + 1

print("Character frequencies:", freq)
# Out:
# Character frequencies: {'b': 1, 'a': 3, 'n': 2}

# %%
# Write a program to create a dictionary where keys are numbers from 1 to 5 and
# values are their squares.

squares = {}

for i in range(1, 6):
    squares[i] = i * i

print("Squares dictionary:", squares)
# Out:
# Squares dictionary: {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
#  Write a program to find the total number of items in the dictionary
# d = {"apple": 5, "banana": 7, "cherry": 3}
d = {"apple": 5, "banana": 7, "cherry": 3}

total_items = len(d)
print("Total number of items:", total_items)
# Out:
# Total number of items: 3

# %%
# Write a program to sort a dictionary by its keys
# d = {3: "three", 1: "one", 2: "two"}
d = {3: "three", 1: "one", 2: "two"}

sorted_dict = {}
for key in sorted(d.keys()):
    sorted_dict[key] = d[key]

print("Sorted by keys:", sorted_dict)
# Out:
# Sorted by keys: {1: 'one', 2: 'two', 3: 'three'}

# %%
# Write a program to count how many values are greater than 50 in a dictionary.

data = {"a": 20, "b": 60, "c": 45, "d": 80, "e": 55}

count = 0
for value in data.values():
    if value > 50:
        count += 1

print("Values greater than 50:", count)
# Out:
# Values greater than 50: 3

# %%
# Write a program to find the key with the highest value in a dictionary.
data = {"a": 20, "b": 60, "c": 45, "d": 80, "e": 55}
