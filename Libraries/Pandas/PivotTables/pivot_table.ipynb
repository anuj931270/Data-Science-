# %%
import numpy as np 
import pandas as pd

# %%
#Pivot Table

data = {
    'Date': pd.date_range('2026-05-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep Month Quarter
# 0  2026-05-01       A   East    652     27   John   May      Q2
# 1  2026-05-02       B   West    608     93   Mary   May      Q2
# 2  2026-05-03       C  North    886     16    Bob   May      Q2
# 3  2026-05-04       D  South    869     92  Alice   May      Q2
# 4  2026-05-05       A   East    574     35   John   May      Q2
# 5  2026-05-06       B   West    100     35   Mary   May      Q2
# 6  2026-05-07       C  North    193     38    Bob   May      Q2
# 7  2026-05-08       D  South    797     71  Alice   May      Q2
# 8  2026-05-09       A   East    252     20   John   May      Q2
# 9  2026-05-10       B   West    767     74   Mary   May      Q2
# 10 2026-05-11       C  North    818     40    Bob   May      Q2
# 11 2026-05-12       D  South    993     36  Alice   May      Q2
# 12 2026-05-13       A   East    592     52   John   May      Q2
# 13 2026-05-14       B   West    826     12   Mary   May      Q2
# 14 2026-05-15       C  North    387     47    Bob   May      Q2
# 15 2026-05-16       D  South    521     98  Alice   May      Q2
# 16 2026-05-17       A   East    927     30   John   May      Q2
# 17 2026-05-18       B   West    676     85   Mary   May      Q2
# 18 2026-05-19       C  North    113     46    Bob   May      Q2
# 19 2026-05-20       D  South    474     81  Alice   May      Q2

# %%
pd.pivot_table(df,values="Sales",index="Region",columns="Product")
# Out:
# Product      A      B      C      D
# Region
# East     599.4    NaN    NaN    NaN
# North      NaN    NaN  479.4    NaN
# South      NaN    NaN    NaN  730.8
# West       NaN  595.4    NaN    NaN

# %%
pivot2=pd.pivot_table(df,values=["Sales","Units"],index="Region",columns="Product")
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     599.4    NaN    NaN    NaN  32.8   NaN   NaN   NaN
# North      NaN    NaN  479.4    NaN   NaN   NaN  37.4   NaN
# South      NaN    NaN    NaN  730.8   NaN   NaN   NaN  75.6
# West       NaN  595.4    NaN    NaN   NaN  59.8   NaN   NaN

# %%
#Cross Tab is used for counting purpose
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
